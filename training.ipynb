# %%
pip install gpt_2_simple
# Out:
# Collecting gpt_2_simple
#   Downloading gpt_2_simple-0.8.1.tar.gz (26 kB)
# Requirement already satisfied: tensorflow>=2.5.1 in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2.8.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2019.12.20)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (4.64.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from gpt_2_simple) (1.21.6)
# Collecting toposort
#   Downloading toposort-1.7-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.6.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.25.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.8.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.8.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.17.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.44.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.2.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.14.0)
# Collecting tf-estimator-nightly==2.8.0.dev2021122109
#   Downloading tf_estimator_nightly-2.8.0.dev2021122109-py2.py3-none-any.whl (462 kB)
#      |████████████████████████████████| 462 kB 6.2 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (57.4.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (0.5.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.0.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (2.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (14.0.1)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (4.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.5.1->gpt_2_simple) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.5.1->gpt_2_simple) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py>=2.9.0->tensorflow>=2.5.1->gpt_2_simple) (1.5.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (3.3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (1.35.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (3.8.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->gpt_2_simple) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.5.1->gpt_2_simple) (3.2.0)
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.8.1-py3-none-any.whl size=24576 sha256=5757b070c8d54a893dbe25ce74f989d79b433d70a575f80960e89cbce92184c3
#   Stored in directory: /root/.cache/pip/wheels/d6/89/8a/f5de6944286d1ac2658b0caa7eae3c8cda50f770cdc957217f
# Successfully built gpt-2-simple
# Installing collected packages: tf-estimator-nightly, toposort, gpt-2-simple
# Successfully installed gpt-2-simple-0.8.1 tf-estimator-nightly-2.8.0.dev2021122109 toposort-1.7

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import os
import tarfile
import gpt_2_simple as gpt2_simple
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
gpt2_simple.download_gpt2(model_name='124M') # Will take sometime....
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 568Mit/s]
# Fetching encoder.json: 1.05Mit [00:01, 591kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 241Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [01:14, 6.68Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 493Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:01, 843kit/s]
# Fetching vocab.bpe: 1.05Mit [00:01, 840kit/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
# ...

tf.compat.v1.reset_default_graph()

# %%
file_name = '/content/drive/MyDrive/text_adventures.txt'
sess = gpt2_simple.start_tf_sess()
gpt2_simple.finetune(
    sess,
    file_name,
    learning_rate=0.0001,
    steps=1000,
    sample_every=200,
    save_every=1000, 
    print_every=10, 
    restore_from='fresh'
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Loading checkpoint models/124M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:48<00:00, 48.51s/it]
# dataset has 10326337 tokens
# Training...
# [10 | 52.63] loss=3.08 avg=3.08
# [20 | 98.33] loss=3.08 avg=3.08
# [30 | 143.96] loss=3.04 avg=3.07
# [40 | 189.46] loss=2.82 avg=3.01
# [50 | 235.02] loss=2.79 avg=2.96
# [60 | 280.65] loss=2.81 avg=2.94
# [70 | 326.18] loss=3.05 avg=2.95
# [80 | 371.78] loss=2.65 avg=2.91
# [90 | 417.35] loss=2.66 avg=2.88
# [100 | 462.92] loss=3.22 avg=2.92
# [110 | 508.78] loss=2.49 avg=2.88
# [120 | 554.74] loss=2.87 avg=2.88
# [130 | 600.58] loss=2.78 avg=2.87
# [140 | 646.36] loss=2.89 avg=2.87
# [150 | 692.17] loss=2.74 avg=2.86
# [160 | 737.98] loss=2.90 avg=2.86
# [170 | 783.82] loss=2.67 avg=2.85
# [180 | 829.65] loss=2.84 avg=2.85
# [190 | 875.54] loss=2.52 avg=2.83
# [200 | 921.43] loss=2.69 avg=2.82
# ======== SAMPLE 1 ========
# . See the page or use the link in the main article’s description.
#
# “So they were trying to get to you?” You ask.
# “Well I’m sure the others didn’t. They ran away from town and made a good excuse to get lost in the woods, even though the rest were busy playing sports with their buddies just like you would.”
# “Sounds like such a stretch!”
# “Well we know we’ll need a better place to live. We’re on the road and it might be faster to drop off someone from your town if everyone else is nearby and that means you can go take them in and take them back.” This is a good place to put them.
#
# The rest of the town has abandoned them for now.
#
# “Okay, okay, okay, we don’t need you. We just need you to be a nice companion.” You say and then look back at the picture on your computer. You can see that there are three guys in the picture and two of them have brown eyes and they’ve all lost their lives. It also seems a fitting description for a girl that was a teenager on a farm, who ended up having an unhappy day afterwards and has only made good friends with another girl, which is probably a better description for a girl that was a young girl with a good personality and she died a bad death.” The guy is still smiling like a sadistic kitten. You can feel it in your gut, or whatever you call it when you look around.
#
# “Alright, okay, so…” you say after a moment (you always feel like giving a fuck) and then you roll your eyes for a few seconds.
#
# “Yeah, really?”
# “Just remember that for some reason they didn’t let you in and they certainly didn’t take any steps to get in!”
# “Yeah, but not to be taken advantage of. I think if they were here it would probably happen anyway.” You say.
# “Yes, there may be some sort of hidden agenda though. Not that they’re going to tell you. But I’m guessing you can’t expect them to be as suspicious and possibly more of a danger here than in town. Not to mention you still don’t know which way this is going to lead.”
# “Okay then. I’ll show you how best I can with respect to this. Don’t you have ANYTHING to hide around like the guy that got injured in the woods did?”
# “Nah, but…you are my companion, it is a skill set that you have.”
# “Okay, I guess so.”
# “I like you. Let's get back to your town. Just remember, I’m not here to hurt you, I’m here to help you.”
# “Alright.
#
# You sit in a dark and dimly coloured tent and walk down the hill, which is not far from another farm. Several people are on the road, but there are actually two boys and girls here, and maybe the only thing that’s different about this is the fact that they’ve stopped here for a moment so you can go back and look at this photo instead.”
#
# You aren’t quite convinced you should go back after all that time you were here, but you’re pretty sure you can look back at it now. The last time you saw them was on a farm in the village, so you don’t need to go back. You take a step back again and think about what the world might have been like in the past, if you had any sense at all. Then you think back to your old life and you wish you lived in a world where the people are more tolerant of anyone and are less suspicious about outsiders.
#
# Well guess what, you can live in a world where the people are less suspicious of outsiders. So much for the old, brutish nature of your society.
#
# The next morning, you are back in town for some rest and to be honest you might have missed this trip had the folks never been there the first time. You’re definitely not going to look anymore.
#
# You figure you should take a few good days break, but you also need to go to the local village and meet up with the village head again. Apparently he is going to say hi then.
#
# “Hey, hey, I see you’re here, what’s wrong with this town?” he says and then leaves.
# > You have to go back to town
# “What are you doing in town?” You ask
#
# [210 | 984.80] loss=2.84 avg=2.83
# [220 | 1030.69] loss=2.91 avg=2.83
# [230 | 1076.55] loss=2.84 avg=2.83
# [240 | 1122.46] loss=2.62 avg=2.82
# [250 | 1168.33] loss=2.95 avg=2.83
# [260 | 1214.20] loss=2.66 avg=2.82
# [270 | 1260.02] loss=3.02 avg=2.83
# [280 | 1305.92] loss=2.68 avg=2.82
# [290 | 1351.81] loss=2.71 avg=2.82
# [300 | 1397.69] loss=2.69 avg=2.81
# [310 | 1443.54] loss=2.68 avg=2.81
# [320 | 1489.35] loss=2.73 avg=2.80
# [330 | 1535.21] loss=2.77 avg=2.80
# [340 | 1581.12] loss=2.69 avg=2.80
# [350 | 1626.95] loss=2.68 avg=2.79
# [360 | 1672.80] loss=2.79 avg=2.79
# [370 | 1718.65] loss=2.93 avg=2.80
# [380 | 1764.49] loss=2.67 avg=2.79
# [390 | 1810.29] loss=2.87 avg=2.80
# [400 | 1856.15] loss=2.79 avg=2.80
# ======== SAMPLE 1 ========
# �
#
# She didn’t know you’d try again.”
# “You don’t need to be that close; you’ve got a lot on your mind at first.”
# “Don’t do that?”
# “No! I’m sure I’ll have to ask my husband about it, though…”
#
# She pulls out her dagger and then you look on her in confusion.
#
# “Well…”
# “Well I mean really you don’t want to try the dagger?”
# “Yes, I don’t want you to try, I really appreciate it! I mean I knew I’d want to see it as long as possible and I know you’ve been talking about it a lot.”
# “Wait…”
# “I’m a bit worried, but I can tell you I love you and I can always tell when you’re done with me!”
#
# She pauses for a few seconds before speaking.
#
# “It does! And then I’m sort of wondering if you would have made a better boyfriend than you are, since you never really were good with someone.”
# “I know! The guy you’re with isn’t your real boyfriend! He’s probably my best friend so he can keep me in line! Like I said, you don’t even know me personally, we were friends the very first time we met, and we don’t really go much.”
# “What is it with a guy that I don’t really want around?”
# “It’s because I have to! I mean I guess being around more girls is the last thing I’ve really gotten my fill of ever! What am I supposed to do when I’m in danger? Why am I not in a situation where I want to fuck you and I’ve already made a lot of progress? But you seem to like it, so why is that? I mean who doesn’t.”
# “You like sex? I mean I didn’t really like you, but I can’t imagine you weren’t a big fan of me when I was younger. I remember your dad getting really interested in you and having you spend time with him.”
# “Oh…” you start.
# “…I dunno how I wanted to be part of this with myself right?”
# “It’s not like it has the benefit of being on my side. I’m more of a role model and role model as a man. I guess I guess I guess it isn’t your fault at all. You were trying to have me be that role model, but…”
# …you still haven’t answered my question.”
#
# Your eyes turn cold, however she continues to speak again.
#
# “I suppose! That’s one of the reasons why I’ve wanted you to come along with me! Because I think you’re all just really fucking nice of course!” she suddenly exclaims from behind you.
# “What? I'm not really that smart! And I’m certainly not the guy to get a woman to fuck you!”
# “No, well in some ways I thought you might like me anyway! You and I have sort of worked together for awhile, and for that we both have very much been together! We worked together on these projects and together we’ve done things we’d never done together!”
# “Yeah, you seem to get a lot of different ideas right now of how you don’t think about it, but like I said you don’t really need to think about it! It was always on you!”
# “I don’t know! It was on all of us! I guess there’s always that way with us! I mean we’m a bit of a circle jerk! But I always really liked how you did with your own boyfriend!”
# “And I remember you were always funny! Anyway I just wanted to take care of that for a moment…”
# “Wait! I always remember you! I was always a little funny! Oh you were always funny, but you never really had any fucking substance.”
#
# You don’t understand why, but you’re not sure. It’s all part of your life now. The past couple years have been a lot of fun, but the fact that you’re not really one of it has certainly given you pause…you haven’
#
# [410 | 1918.42] loss=2.69 avg=2.79
# [420 | 1964.29] loss=2.93 avg=2.80
# [430 | 2010.11] loss=2.94 avg=2.80
# [440 | 2055.93] loss=2.64 avg=2.80
# [450 | 2101.82] loss=2.49 avg=2.79
# [460 | 2147.66] loss=2.75 avg=2.79
# [470 | 2193.42] loss=2.56 avg=2.78
# [480 | 2239.21] loss=2.80 avg=2.78
# [490 | 2285.09] loss=2.62 avg=2.78
# [500 | 2330.91] loss=2.94 avg=2.78
# [510 | 2376.78] loss=2.77 avg=2.78
# [520 | 2422.61] loss=2.66 avg=2.78
# [530 | 2468.42] loss=2.56 avg=2.77
# [540 | 2514.29] loss=2.63 avg=2.77
# [550 | 2560.11] loss=2.91 avg=2.77
# [560 | 2605.92] loss=2.75 avg=2.77
# [570 | 2651.76] loss=2.37 avg=2.76
# [580 | 2697.61] loss=2.76 avg=2.76
# [590 | 2743.49] loss=2.66 avg=2.76
# [600 | 2789.32] loss=2.80 avg=2.76
# ======== SAMPLE 1 ========
#  to a new world of possibility.
#
#
#
#
#
#
#
# > You become the Vampire
#
#
# Life
#
#
#
#
#
#
# And death
#
#
#
#
#
#
# It may sound like a complicated story of a nobleman to the average citizen, but it is one of the most unique. As a vampire, you would feel obligated to be as loyal to the Felkan Empire as you would be to your master's side if that meant serving under an equal amount of scrutiny. Not that this is an issue to the Vampire Counts, and you could serve as one of their new allies if they wished, but you feel the need to be a dedicated follower of Fel.
# > You stay with the Vampire
#
#
# Your loyalty to the Felkan Empire is so strong, you decide to become an advisor to the Vampire Counts instead of a loyal servant.
#
#
#
#
# > You become a follower of Fel
#
#
# Your loyalty to the Felkan Empire is so strong, you decide to become an advisor to the Vampire Counts instead of a loyal servant.
#
#
#
#
#
#
# You’ve decided to stay loyal to the Felkan Empire and as the vampire count rises, you take that decision to be,
#
# “Yes, I’ll take over as general commander of the Vampire Counts.
#
#
#
#
# Your loyalty to the Felkan Empire is so strong, you decide to become an advisor to the Vampire Counts instead of a loyal servant.
#
# You’ve decided to stay loyal to the Felkan Empire and as the vampire count rises, you take that decision to be,
#
# “Yes, I'll take over as general commander of the Vampire Counts.
#
# You decided to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
# “Yes, I'll take over as general commander of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “Yes, I'll take over as general commander of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “Yes, I'll take over as general commander of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “ Yes, I'll take over as general commander of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “Yes, I'll take over as general commanding of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “ Yes, I'll take over as General commanding of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “ Yes, I'll take over as General commanding of the Vampire Counts.
#
# You decide to stay loyal to the Felkan Empire and as the Vampire count rises, you take that decision to be,
#
# “ Yes, I'll take over as General commanding of the Vampire Counts.
#
# You are now serving Vampire Counts in your own world. Even on your journey through the dark and barren lands, your life is now an endless source of power.
#
# You are now serving the Light in your own world,
# “I’ll serve your life”
#
#
# You begin to think about going back to Hell.  But you know your fate,
#
# “Yes, I will become a follower of the Darkness in your own world and serve
#
# your life and your soul on a higher plane.
#
#
#
#
#
#
# > You go back to Hell
#
#
# You go back to the afterlife, while you’re still in the aftermath of these events.  You start getting angry that this wasn’t the right choice, and you’re becoming more violent with it.
#
#
#
#
#
#
#
# You begin to take a much greater liking for the Darkness and the Eternal Dominion.
#
#
#
#
#
#
#
#
#
# You begin to become more aggressive.  You’re beginning to think about leaving.
#
#
#
#
#
# You begin to think about leaving.  You’re starting to think of the very things you were meant to serve.  You start to try to re-
#
# [610 | 2851.42] loss=3.02 avg=2.77
# [620 | 2897.24] loss=2.65 avg=2.76
# [630 | 2943.09] loss=2.75 avg=2.76
# [640 | 2988.93] loss=2.48 avg=2.76
# [650 | 3034.75] loss=3.00 avg=2.76
# [660 | 3080.60] loss=2.85 avg=2.77
# [670 | 3126.47] loss=2.83 avg=2.77
# [680 | 3172.30] loss=2.96 avg=2.77
# [690 | 3218.19] loss=2.78 avg=2.77
# [700 | 3263.99] loss=2.90 avg=2.77
# [710 | 3309.80] loss=2.47 avg=2.77
# [720 | 3355.65] loss=2.46 avg=2.76
# [730 | 3401.58] loss=2.58 avg=2.76
# [740 | 3447.49] loss=2.90 avg=2.76
# [750 | 3493.34] loss=2.48 avg=2.76
# [760 | 3539.20] loss=2.55 avg=2.75
# [770 | 3585.09] loss=2.73 avg=2.75
# [780 | 3630.94] loss=2.63 avg=2.75
# [790 | 3676.80] loss=2.69 avg=2.75
# [800 | 3722.78] loss=2.56 avg=2.74
# ======== SAMPLE 1 ========
#  head out to the town, you don’t even bother taking a cab as it’s more convenient. You have a good deal of confidence in your abilities that don’t need to be improved. Granted you aren’t nearly as fast as you should be, but you still have that good shot you had against someone with a cane.
#
# “Well, we were still here then, but I guess I can take the advantage of it. The place is mostly empty now, and after getting in it is a lot more accessible, well what I want is for them to see as well since I can easily move and shoot people, since at least the locals are a bit more concerned about being shot. Now if only we hadn’t been running away from the whole place too.” You says.
# “I dunno, well you could probably convince those other towns to put you in there somehow. But I dunno, you guys are probably not going to be the best team.”
# “Geez. I still think they’ll get me someplace safer than this.”
# “I’m going to be the best.”
# “That’s not going to be easy. The place is starting to look like shit! There isn’t even any water, there’s no running water, there wouldn’t really be any way to make any money off of it and since you have the best weapons available, you might as well do it if that didn’t involve you being in more pain.”
#
# You hear the door open and immediately start laughing, but then you hear several people laughing too. Probably like some mutant mutant girl or something.
#
# “Shit, I’ll’ve got you and that guy and that shithead!” you hear the crowd shout.
# “Yeah fuck that and that, they were the ones here with me and they didn’t even let me take advantage of it!” a woman shouts.
#
# You and a couple of the other women look at each other and then look at each other. This one is a bit shocked.
#
# “Uh, look at that bloody bastard asshole who got here, you think he is going to get the hell out after he ran around with a knife in his mouth? Come on, it isn’t some random chick I guess.” You exclaim.
# “No…nevermind, it’s me.” Another woman who you’ve never seen before points.
# “I got a friend here, but he is a clown and he killed himself anyway. Well this is it, he isn’t going anywhere.” You say.
# “The clowns are coming for him anyway…this is just really dangerous.”
# “Yeah, you’re right. You could just tell whoever else did this that that shit was going to come at them. The other clown’s ass went to them. I mean even if they didn’t actually put weapons out the window while I was going out, I think they probably figured I would probably get killed so they’d know I was going to get shot myself if I stayed here.”
# “Yeah, you guess that’s one of the reasons why they even stayed alive.” You answer.
#
# At this point a man takes part in what you don’t want to be known as a “fight”. Your guess is that as soon as he sees you, he’s going to go over there and cause you harm, though you aren’t sure if that is something he will be getting from the clowns or not.
#
# Apparently clowns don’t like clown fights, though that doesn’t mean they don’t like clowns too much, it seems that there is some underground activity going on with clowns in this part of town. A few of them even got involved with the Klyton militia when the National Guard troops were stationed in the area. A couple got in fights with them, but it didn’t really bother them or the clowns. It just showed up on their faces when they fought one of them back.
#
# You get a couple clowns who are trying to be friendly, but when a bunch of clowns come in with rifles and pistols, that might really hurt them. You just don’t think you might be able to bring them the gun that they don’t even have. You aren’t sure they’d accept that.
#
# A couple of the clowns leave for a couple more places and you think you’re in even worse danger than you’re in. You know you’ve been out of sight and out of mind for a
#
# [810 | 3784.97] loss=2.46 avg=2.74
# [820 | 3830.86] loss=2.86 avg=2.74
# [830 | 3876.77] loss=2.65 avg=2.74
# [840 | 3922.74] loss=2.31 avg=2.73
# [850 | 3968.67] loss=3.08 avg=2.74
# [860 | 4014.57] loss=2.72 avg=2.74
# [870 | 4060.52] loss=2.70 avg=2.74
# [880 | 4106.43] loss=2.71 avg=2.74
# [890 | 4152.34] loss=2.61 avg=2.73
# [900 | 4198.20] loss=2.49 avg=2.73
# [910 | 4244.08] loss=2.88 avg=2.73
# [920 | 4289.87] loss=2.66 avg=2.73
# [930 | 4335.77] loss=2.45 avg=2.73
# [940 | 4381.71] loss=2.62 avg=2.72
# [950 | 4427.63] loss=2.46 avg=2.72
# [960 | 4473.41] loss=2.57 avg=2.72
# [970 | 4519.17] loss=2.51 avg=2.71
# [980 | 4565.02] loss=2.48 avg=2.71
# [990 | 4610.87] loss=2.66 avg=2.71
# [1000 | 4656.67] loss=2.65 avg=2.71
# Saving checkpoint/run1/model-1000

# %%
gpt2_simple.copy_checkpoint_to_gdrive(run_name='run1')

# %%
gpt2_simple.generate(sess)
